# %%
import pandas as pd

# %%
df = pd.read_csv("stock_data.csv")

# %%
df
# Out:
#   stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
df2 = pd.read_csv("stock_data.csv", skiprows=1)

# %%
df2
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
# Another way to skip the first row
df3 = pd.read_csv("stock_data.csv", header=1)

# %%
df3
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
#Suppose i have no header
df4 = pd.read_csv("stock_data.csv", header = None)

# %%
df4
# Out:
#        0              1    2     3              4
# 0  GOOGL          27.82   87   845     larry page
# 1    WMT           4.61  484    65           n.a.
# 2   MSFT             -1   85    64     bill gates
# 3   RIL   not available   50  1023  mukesh ambani
# 4   TATA            5.6   -1  n.a.     ratan tata

# %%
#Provide the header
df5 = pd.read_csv("stock_data.csv", header=None, names=["tickers", "eps", "revenue", "price", "people"])

# %%
df5
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", nrows=3)

# %%
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates
